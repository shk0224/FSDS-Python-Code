# %% [markdown]
# #Our First Python Program

# %%
print("Hello World")

# %%
print ('Hello Wold')

# %%
print ('Inception BD')

# %%
Print(Inception BD)

# %%
print(9)

# %%
print(9.9)

# %%
print(true)

# %%
print("Helloo",1,2,3,      4, 6.6, True, sep="-")

# %%
print("shuvo", end='    ')
print("inception")

# %% [markdown]
# #Data Type in Python

# %%
print ("9")

# %%
#List
print([1,2,5])

# %%
type    ([1,2,5])

# %%
#Tuple
print((1,2,6))

# %%
type   ((1,2,6))

# %%
#Sets
print ({1,4,5})

# %%
type ({1,4,5})

# %%
#Dictionary
print({"Name":  "SD","Age":31})

# %%
type ({"Name":  "SD","Age":31})

# %%
name="Shuvo"
print("Welcome", name,sep=' my man.....', end="     ;;;;")
print("Welcome", name, end=" bosss")

# %%
a=7
a="Sd"
print    (a)

# %%
a=5
print(a)
a="ShuvoD"
print(a)

# %%
a

# %%
input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1290019835.py in <cell line: 0>()
# ----> 1 input()
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
vari=input()

# %%
vari

# %%
print(vari)

# %%
type(vari)

# %%
float(vari)

# %%
type(vari)

# %%
vari=float(vari)

# %%
type(vari)

# %%
vari

# %%
var=input('Enter your name:    ')
print(var)
# Out:
# Enter your name:    shuvoDu
# shuvoDu

# %%
a= float(input("Enter first number: "))
b= float(input("Enter second number: "))

additionresult= a+b
print("Your result is here", additionresult, sep='-----')
# Out:
# Enter first number: 2
# Enter second number: 5
# Your result is here-----7.0

# %%
a=5+5.7
print(a)
type(a)
# Out:
# 10.7
# float

# %%
number=35
number=float(number)
print(number)
# Out:
# 35.0

# %%
type(number)
# Out:
# float

# %% [markdown]
# # Literals in Python

# %%
a=4
print(type(a))
# Out:
# <class 'int'>
